# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# %%
archivo = pd.read_csv("EntireDump.csv")

# %%
splited = archivo.FECHA.str.split('/', expand=True)

# %%
final = pd.concat([archivo, splited], axis=1, join='inner')
final.head()
# Out:
#         FECHA    CODPRO  CANTID   NETO   0   1     2
# 0  30/07/2018  DS462545       1  16490  30  07  2018
# 1  30/07/2018  DS460974       1  15490  30  07  2018
# 2  30/07/2018  DS454484       1  86490  30  07  2018
# 3  30/07/2018  DS461220       1  37807  30  07  2018
# 4  30/07/2018  DS454484       1  86490  30  07  2018

# %%
serie = pd.DataFrame({ 'A' : range(0, 1918 ,1)})

# %%
plt.figure(figsize=(50,20))
plt.plot(serie['A'],final['NETO'])
plt.show()

# %%
final.describe()
# Out:
#             CANTID          NETO
# count  1918.000000  1.918000e+03
# mean      1.901981  8.209126e+04
# std       2.646990  2.277909e+05
# min       1.000000  1.490000e+03
# 25%       1.000000  1.400000e+04
# 50%       1.000000  2.812050e+04
# 75%       2.000000  6.725050e+04
# max      41.000000  5.596350e+06
