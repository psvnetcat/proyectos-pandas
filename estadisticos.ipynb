# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.plotting import autocorrelation_plot

# %%
archivo = pd.read_csv("MonthDump.csv")

# %%
archivo.head()
# Out:
#        MES    VENTAS  CANTIDAD
# 0  12/2017   4403552        94
# 1  11/2017   6478447        39
# 2  10/2017    696776         7
# 3  07/2018  39756849      1194
# 4  06/2018  27367388       654

# %%
splited = archivo.MES.str.split('/', expand=True)

# %%
final = pd.concat([archivo, splited], axis=1, join='inner')
final.head()
# Out:
#        MES    VENTAS  CANTIDAD   0     1
# 0  12/2017   4403552        94  12  2017
# 1  11/2017   6478447        39  11  2017
# 2  10/2017    696776         7  10  2017
# 3  07/2018  39756849      1194  07  2018
# 4  06/2018  27367388       654  06  2018

# %%
serie = pd.DataFrame({ 'A' : range(0, final.shape[0] ,1)})

# %%
plt.figure(figsize=(50,20))
plt.plot(serie['A'],final['VENTAS'])
plt.show()

# %%
plt.figure(figsize=(50,20))
plt.plot(serie['A'],final['CANTIDAD'])
plt.show()

# %%
final['CANTIDAD'].autocorr()
# Out:
# 0.2491019441727461

# %%
plt.figure(figsize=(50,20))
autocorrelation_plot(final['VENTAS'])
